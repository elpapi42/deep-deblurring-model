# %% [markdown]
# This Notebook will present the results of the Exploratory Data Analysis

# %% [markdown]
# # Clone Repository

# %%
# Executes the cell in bash mode
# %%bash

if [ ! -d "/content/deep-deblurring/" ]; 
    then 
        git clone https://github.com/ElPapi42/deep-deblurring;
        cd deep-deblurring/
    else 
        cd deep-deblurring/; 
        git pull; 
fi;

git checkout development
cd ..
# Out:
# Branch 'alt_loop' set up to track remote branch 'alt_loop' from 'origin'.
# Cloning into 'deep-deblurring'...
# Switched to a new branch 'alt_loop'

# %% [markdown]
# # Install Requirements

# %%
# Executes the cell in bash mode
# %%bash

#pip uninstall -y tensorflow tensor2tensor tensorboard tensorboardcolab tensorflow-datasets tensorflow-estimator tensorflow-gan tensorflow-hub tensorflow-metadata tensorflow-privacy tensorflow-probability

pip install colab-env
pip install --upgrade grpcio

pip install -r "/content/deep-deblurring/requirements.txt"

cd deep-deblurring/
python setup.py install
cd ..
# Out:
# Collecting colab-env
#   Downloading https://files.pythonhosted.org/packages/9d/66/1845bc28d685894e6e203cfb2bdd9d19c86926d7a6f765e9497e218ab304/colab-env-0.2.0.tar.gz
# Collecting python-dotenv<1.0,>=0.10.0
#   Downloading https://files.pythonhosted.org/packages/7f/ee/e0cd2d8ba548e4c3e8c9e70d76e423b3e8b8e4eec351f51292d828c735d2/python_dotenv-0.12.0-py2.py3-none-any.whl
# Building wheels for collected packages: colab-env
#   Building wheel for colab-env (setup.py): started
#   Building wheel for colab-env (setup.py): finished with status 'done'
#   Created wheel for colab-env: filename=colab_env-0.2.0-cp36-none-any.whl size=3838 sha256=30e82e9ef4768db124ff39a33fc8332b3f5555261d31e3773b8082c094d83705
#   Stored in directory: /root/.cache/pip/wheels/81/9c/85/7ec1faca43d1a5df32f33f4e22d5ae91f301a5406779528ead
# Successfully built colab-env
# Installing collected packages: python-dotenv, colab-env
# Successfully installed colab-env-0.2.0 python-dotenv-0.12.0
# Requirement already up-to-date: grpcio in /usr/local/lib/python3.6/dist-packages (1.27.2)
# Requirement already satisfied, skipping upgrade: six>=1.5.2 in /usr/local/lib/python3.6/dist-packages (from grpcio) (1.12.0)
# Requirement already satisfied: grpcio==1.27.2 in /usr/local/lib/python3.6/dist-packages (from -r /content/deep-deblurring/requirements.txt (line 1)) (1.27.2)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (from -r /content/deep-deblurring/requirements.txt (line 2)) (1.5.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from -r /content/deep-deblurring/requirements.txt (line 3)) (1.18.2)
# Requirement already satisfied: tensorflow>=2.2.0rc2 in /usr/local/lib/python3.6/dist-packages (from -r /content/deep-deblurring/requirements.txt (line 4)) (2.2.0rc2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from -r /content/deep-deblurring/requirements.txt (line 5)) (1.0.3)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.6/dist-packages (from grpcio==1.27.2->-r /content/deep-deblurring/requirements.txt (line 1)) (1.12.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle->-r /content/deep-deblurring/requirements.txt (line 2)) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle->-r /content/deep-deblurring/requirements.txt (line 2)) (2019.11.28)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle->-r /content/deep-deblurring/requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle->-r /content/deep-deblurring/requirements.txt (line 2)) (4.38.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle->-r /content/deep-deblurring/requirements.txt (line 2)) (2.21.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle->-r /content/deep-deblurring/requirements.txt (line 2)) (2.8.1)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (1.12.1)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (2.10.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (3.2.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.3.0,>=2.2.0rc0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (2.2.0rc0)
# Requirement already satisfied: tensorboard<2.3.0,>=2.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (2.2.0)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (1.4.1)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (0.3.3)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (0.34.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (0.9.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (3.10.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->-r /content/deep-deblurring/requirements.txt (line 5)) (2018.9)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle->-r /content/deep-deblurring/requirements.txt (line 2)) (1.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle->-r /content/deep-deblurring/requirements.txt (line 2)) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle->-r /content/deep-deblurring/requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (3.2.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (46.0.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (1.7.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (1.6.0.post2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (4.0)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (3.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (0.2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow>=2.2.0rc2->-r /content/deep-deblurring/requirements.txt (line 4)) (0.4.8)
# running install
# running bdist_egg
# running egg_info
# creating deblurrer.egg-info
# writing deblurrer.egg-info/PKG-INFO
# writing dependency_links to deblurrer.egg-info/dependency_links.txt
# writing requirements to deblurrer.egg-info/requires.txt
# writing top-level names to deblurrer.egg-info/top_level.txt
# writing manifest file 'deblurrer.egg-info/SOURCES.txt'
# writing manifest file 'deblurrer.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/deblurrer
# copying deblurrer/__init__.py -> build/lib/deblurrer
# creating build/lib/tests
# copying tests/__init__.py -> build/lib/tests
# copying tests/fixtures.py -> build/lib/tests
# creating build/lib/deblurrer/model
# copying deblurrer/model/losses.py -> build/lib/deblurrer/model
# copying deblurrer/model/deblurgan.py -> build/lib/deblurrer/model
# copying deblurrer/model/__init__.py -> build/lib/deblurrer/model
# creating build/lib/deblurrer/scripts
# copying deblurrer/scripts/__init__.py -> build/lib/deblurrer/scripts
# creating build/lib/deblurrer/model/generator
# copying deblurrer/model/generator/generator.py -> build/lib/deblurrer/model/generator
# copying deblurrer/model/generator/__init__.py -> build/lib/deblurrer/model/generator
# copying deblurrer/model/generator/backbone.py -> build/lib/deblurrer/model/generator
# copying deblurrer/model/generator/fpn.py -> build/lib/deblurrer/model/generator
# creating build/lib/deblurrer/model/discriminator
# copying deblurrer/model/discriminator/dglobal.py -> build/lib/deblurrer/model/discriminator
# copying deblurrer/model/discriminator/local.py -> build/lib/deblurrer/model/discriminator
# copying deblurrer/model/discriminator/__init__.py -> build/lib/deblurrer/model/discriminator
# copying deblurrer/model/discriminator/discriminator.py -> build/lib/deblurrer/model/discriminator
# creating build/lib/deblurrer/scripts/training
# copying deblurrer/scripts/training/tester.py -> build/lib/deblurrer/scripts/training
# copying deblurrer/scripts/training/test.py -> build/lib/deblurrer/scripts/training
# copying deblurrer/scripts/training/trainer.py -> build/lib/deblurrer/scripts/training
# copying deblurrer/scripts/training/__init__.py -> build/lib/deblurrer/scripts/training
# copying deblurrer/scripts/training/alt_train.py -> build/lib/deblurrer/scripts/training
# copying deblurrer/scripts/training/train.py -> build/lib/deblurrer/scripts/training
# creating build/lib/deblurrer/scripts/datasets
# copying deblurrer/scripts/datasets/kaggle_blur.py -> build/lib/deblurrer/scripts/datasets
# copying deblurrer/scripts/datasets/compile_all.py -> build/lib/deblurrer/scripts/datasets
# copying deblurrer/scripts/datasets/generate_dataset.py -> build/lib/deblurrer/scripts/datasets
# copying deblurrer/scripts/datasets/generate_csv.py -> build/lib/deblurrer/scripts/datasets
# copying deblurrer/scripts/datasets/download.py -> build/lib/deblurrer/scripts/datasets
# copying deblurrer/scripts/datasets/__init__.py -> build/lib/deblurrer/scripts/datasets
# copying deblurrer/scripts/datasets/generate_tfrecord.py -> build/lib/deblurrer/scripts/datasets
# creating build/lib/tests/model
# copying tests/model/discriminator_test.py -> build/lib/tests/model
# copying tests/model/__init__.py -> build/lib/tests/model
# copying tests/model/generator_test.py -> build/lib/tests/model
# copying tests/model/losses_test.py -> build/lib/tests/model
# creating build/lib/tests/scripts
# copying tests/scripts/__init__.py -> build/lib/tests/scripts
# creating build/lib/tests/scripts/training
# copying tests/scripts/training/trainer_test.py -> build/lib/tests/scripts/training
# copying tests/scripts/training/tester_test.py -> build/lib/tests/scripts/training
# copying tests/scripts/training/__init__.py -> build/lib/tests/scripts/training
# creating build/lib/deblurrer/colab
# copying deblurrer/colab/TrainBook.ipynb -> build/lib/deblurrer/colab
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/deblurrer
# creating build/bdist.linux-x86_64/egg/deblurrer/colab
# copying build/lib/deblurrer/colab/TrainBook.ipynb -> build/bdist.linux-x86_64/egg/deblurrer/colab
# creating build/bdist.linux-x86_64/egg/deblurrer/model
# copying build/lib/deblurrer/model/losses.py -> build/bdist.linux-x86_64/egg/deblurrer/model
# creating build/bdist.linux-x86_64/egg/deblurrer/model/generator
# copying build/lib/deblurrer/model/generator/generator.py -> build/bdist.linux-x86_64/egg/deblurrer/model/generator
# copying build/lib/deblurrer/model/generator/__init__.py -> build/bdist.linux-x86_64/egg/deblurrer/model/generator
# copying build/lib/deblurrer/model/generator/backbone.py -> build/bdist.linux-x86_64/egg/deblurrer/model/generator
# copying build/lib/deblurrer/model/generator/fpn.py -> build/bdist.linux-x86_64/egg/deblurrer/model/generator
# copying build/lib/deblurrer/model/deblurgan.py -> build/bdist.linux-x86_64/egg/deblurrer/model
# copying build/lib/deblurrer/model/__init__.py -> build/bdist.linux-x86_64/egg/deblurrer/model
# creating build/bdist.linux-x86_64/egg/deblurrer/model/discriminator
# copying build/lib/deblurrer/model/discriminator/dglobal.py -> build/bdist.linux-x86_64/egg/deblurrer/model/discriminator
# copying build/lib/deblurrer/model/discriminator/local.py -> build/bdist.linux-x86_64/egg/deblurrer/model/discriminator
# copying build/lib/deblurrer/model/discriminator/__init__.py -> build/bdist.linux-x86_64/egg/deblurrer/model/discriminator
# copying build/lib/deblurrer/model/discriminator/discriminator.py -> build/bdist.linux-x86_64/egg/deblurrer/model/discriminator
# copying build/lib/deblurrer/__init__.py -> build/bdist.linux-x86_64/egg/deblurrer
# creating build/bdist.linux-x86_64/egg/deblurrer/scripts
# creating build/bdist.linux-x86_64/egg/deblurrer/scripts/training
# copying build/lib/deblurrer/scripts/training/tester.py -> build/bdist.linux-x86_64/egg/deblurrer/scripts/training
# copying build/lib/deblurrer/scripts/training/test.py -> build/bdist.linux-x86_64/egg/deblurrer/scripts/training
# copying build/lib/deblurrer/scripts/training/trainer.py -> build/bdist.linux-x86_64/egg/deblurrer/scripts/training
# copying build/lib/deblurrer/scripts/training/__init__.py -> build/bdist.linux-x86_64/egg/deblurrer/scripts/training
# copying build/lib/deblurrer/scripts/training/alt_train.py -> build/bdist.linux-x86_64/egg/deblurrer/scripts/training
# copying build/lib/deblurrer/scripts/training/train.py -> build/bdist.linux-x86_64/egg/deblurrer/scripts/training
# copying build/lib/deblurrer/scripts/__init__.py -> build/bdist.linux-x86_64/egg/deblurrer/scripts
# creating build/bdist.linux-x86_64/egg/deblurrer/scripts/datasets
# copying build/lib/deblurrer/scripts/datasets/kaggle_blur.py -> build/bdist.linux-x86_64/egg/deblurrer/scripts/datasets
# copying build/lib/deblurrer/scripts/datasets/compile_all.py -> build/bdist.linux-x86_64/egg/deblurrer/scripts/datasets
# copying build/lib/deblurrer/scripts/datasets/generate_dataset.py -> build/bdist.linux-x86_64/egg/deblurrer/scripts/datasets
# copying build/lib/deblurrer/scripts/datasets/generate_csv.py -> build/bdist.linux-x86_64/egg/deblurrer/scripts/datasets
# copying build/lib/deblurrer/scripts/datasets/download.py -> build/bdist.linux-x86_64/egg/deblurrer/scripts/datasets
# copying build/lib/deblurrer/scripts/datasets/__init__.py -> build/bdist.linux-x86_64/egg/deblurrer/scripts/datasets
# copying build/lib/deblurrer/scripts/datasets/generate_tfrecord.py -> build/bdist.linux-x86_64/egg/deblurrer/scripts/datasets
# creating build/bdist.linux-x86_64/egg/tests
# creating build/bdist.linux-x86_64/egg/tests/model
# copying build/lib/tests/model/discriminator_test.py -> build/bdist.linux-x86_64/egg/tests/model
# copying build/lib/tests/model/__init__.py -> build/bdist.linux-x86_64/egg/tests/model
# copying build/lib/tests/model/generator_test.py -> build/bdist.linux-x86_64/egg/tests/model
# copying build/lib/tests/model/losses_test.py -> build/bdist.linux-x86_64/egg/tests/model
# copying build/lib/tests/__init__.py -> build/bdist.linux-x86_64/egg/tests
# copying build/lib/tests/fixtures.py -> build/bdist.linux-x86_64/egg/tests
# creating build/bdist.linux-x86_64/egg/tests/scripts
# creating build/bdist.linux-x86_64/egg/tests/scripts/training
# copying build/lib/tests/scripts/training/trainer_test.py -> build/bdist.linux-x86_64/egg/tests/scripts/training
# copying build/lib/tests/scripts/training/tester_test.py -> build/bdist.linux-x86_64/egg/tests/scripts/training
# copying build/lib/tests/scripts/training/__init__.py -> build/bdist.linux-x86_64/egg/tests/scripts/training
# copying build/lib/tests/scripts/__init__.py -> build/bdist.linux-x86_64/egg/tests/scripts
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/model/losses.py to losses.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/model/generator/generator.py to generator.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/model/generator/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/model/generator/backbone.py to backbone.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/model/generator/fpn.py to fpn.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/model/deblurgan.py to deblurgan.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/model/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/model/discriminator/dglobal.py to dglobal.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/model/discriminator/local.py to local.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/model/discriminator/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/model/discriminator/discriminator.py to discriminator.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/scripts/training/tester.py to tester.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/scripts/training/test.py to test.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/scripts/training/trainer.py to trainer.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/scripts/training/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/scripts/training/alt_train.py to alt_train.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/scripts/training/train.py to train.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/scripts/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/scripts/datasets/kaggle_blur.py to kaggle_blur.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/scripts/datasets/compile_all.py to compile_all.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/scripts/datasets/generate_dataset.py to generate_dataset.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/scripts/datasets/generate_csv.py to generate_csv.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/scripts/datasets/download.py to download.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/scripts/datasets/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/deblurrer/scripts/datasets/generate_tfrecord.py to generate_tfrecord.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/model/discriminator_test.py to discriminator_test.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/model/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/model/generator_test.py to generator_test.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/model/losses_test.py to losses_test.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/fixtures.py to fixtures.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/scripts/training/trainer_test.py to trainer_test.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/scripts/training/tester_test.py to tester_test.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/scripts/training/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tests/scripts/__init__.py to __init__.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying deblurrer.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying deblurrer.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying deblurrer.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying deblurrer.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying deblurrer.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating dist
# creating 'dist/deblurrer-1.0.0-py3.6.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing deblurrer-1.0.0-py3.6.egg
# creating /usr/local/lib/python3.6/dist-packages/deblurrer-1.0.0-py3.6.egg
# Extracting deblurrer-1.0.0-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# Adding deblurrer 1.0.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/deblurrer-1.0.0-py3.6.egg
# Processing dependencies for deblurrer==1.0.0
# Searching for pandas==1.0.3
# Best match: pandas 1.0.3
# Adding pandas 1.0.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for tensorflow==2.2.0rc2
# Best match: tensorflow 2.2.0rc2
# Adding tensorflow 2.2.0rc2 to easy-install.pth file
# Installing estimator_ckpt_converter script to /usr/local/bin
# Installing saved_model_cli script to /usr/local/bin
# Installing tensorboard script to /usr/local/bin
# Installing tf_upgrade_v2 script to /usr/local/bin
# Installing tflite_convert script to /usr/local/bin
# Installing toco script to /usr/local/bin
# Installing toco_from_protos script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for numpy==1.18.2
# Best match: numpy 1.18.2
# Adding numpy 1.18.2 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.6 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for kaggle==1.5.6
# Best match: kaggle 1.5.6
# Adding kaggle 1.5.6 to easy-install.pth file
# Installing kaggle script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for grpcio==1.27.2
# Best match: grpcio 1.27.2
# Adding grpcio 1.27.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pytz==2018.9
# Best match: pytz 2018.9
# Adding pytz 2018.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for python-dateutil==2.8.1
# Best match: python-dateutil 2.8.1
# Adding python-dateutil 2.8.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for six==1.12.0
# Best match: six 1.12.0
# Adding six 1.12.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Keras-Preprocessing==1.1.0
# Best match: Keras-Preprocessing 1.1.0
# Adding Keras-Preprocessing 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for scipy==1.4.1
# Best match: scipy 1.4.1
# Adding scipy 1.4.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for google-pasta==0.2.0
# Best match: google-pasta 0.2.0
# Adding google-pasta 0.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for wrapt==1.12.1
# Best match: wrapt 1.12.1
# Adding wrapt 1.12.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for tensorboard==2.2.0
# Best match: tensorboard 2.2.0
# Adding tensorboard 2.2.0 to easy-install.pth file
# Installing tensorboard script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for gast==0.3.3
# Best match: gast 0.3.3
# Adding gast 0.3.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for astunparse==1.6.3
# Best match: astunparse 1.6.3
# Adding astunparse 1.6.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for absl-py==0.9.0
# Best match: absl-py 0.9.0
# Adding absl-py 0.9.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for termcolor==1.1.0
# Best match: termcolor 1.1.0
# Adding termcolor 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for tensorflow-estimator==2.2.0rc0
# Best match: tensorflow-estimator 2.2.0rc0
# Adding tensorflow-estimator 2.2.0rc0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for opt-einsum==3.2.0
# Best match: opt-einsum 3.2.0
# Adding opt-einsum 3.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for protobuf==3.10.0
# Best match: protobuf 3.10.0
# Adding protobuf 3.10.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for wheel==0.34.2
# Best match: wheel 0.34.2
# Adding wheel 0.34.2 to easy-install.pth file
# Installing wheel script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for h5py==2.10.0
# Best match: h5py 2.10.0
# Adding h5py 2.10.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for requests==2.21.0
# Best match: requests 2.21.0
# Adding requests 2.21.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for urllib3==1.24.3
# Best match: urllib3 1.24.3
# Adding urllib3 1.24.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for tqdm==4.38.0
# Best match: tqdm 4.38.0
# Adding tqdm 4.38.0 to easy-install.pth file
# Installing tqdm script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for python-slugify==4.0.0
# Best match: python-slugify 4.0.0
# Adding python-slugify 4.0.0 to easy-install.pth file
# Installing slugify script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for certifi==2019.11.28
# Best match: certifi 2019.11.28
# Adding certifi 2019.11.28 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for tensorboard-plugin-wit==1.6.0.post2
# Best match: tensorboard-plugin-wit 1.6.0.post2
# Adding tensorboard-plugin-wit 1.6.0.post2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Werkzeug==1.0.0
# Best match: Werkzeug 1.0.0
# Adding Werkzeug 1.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for google-auth==1.7.2
# Best match: google-auth 1.7.2
# Adding google-auth 1.7.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for setuptools==46.0.0
# Best match: setuptools 46.0.0
# Adding setuptools 46.0.0 to easy-install.pth file
# Installing easy_install script to /usr/local/bin
# Installing easy_install-3.8 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Markdown==3.2.1
# Best match: Markdown 3.2.1
# Adding Markdown 3.2.1 to easy-install.pth file
# Installing markdown_py script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for google-auth-oauthlib==0.4.1
# Best match: google-auth-oauthlib 0.4.1
# Adding google-auth-oauthlib 0.4.1 to easy-install.pth file
# Installing google-oauthlib-tool script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for idna==2.8
# Best match: idna 2.8
# Adding idna 2.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for chardet==3.0.4
# Best match: chardet 3.0.4
# Adding chardet 3.0.4 to easy-install.pth file
# Installing chardetect script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for text-unidecode==1.3
# Best match: text-unidecode 1.3
# Adding text-unidecode 1.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for cachetools==3.1.1
# Best match: cachetools 3.1.1
# Adding cachetools 3.1.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pyasn1-modules==0.2.8
# Best match: pyasn1-modules 0.2.8
# Adding pyasn1-modules 0.2.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for rsa==4.0
# Best match: rsa 4.0
# Adding rsa 4.0 to easy-install.pth file
# Installing pyrsa-decrypt script to /usr/local/bin
# Installing pyrsa-encrypt script to /usr/local/bin
# Installing pyrsa-keygen script to /usr/local/bin
# Installing pyrsa-priv2pub script to /usr/local/bin
# Installing pyrsa-sign script to /usr/local/bin
# Installing pyrsa-verify script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for requests-oauthlib==1.3.0
# Best match: requests-oauthlib 1.3.0
# Adding requests-oauthlib 1.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pyasn1==0.4.8
# Best match: pyasn1 0.4.8
# Adding pyasn1 0.4.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for oauthlib==3.1.0
# Best match: oauthlib 3.1.0
# Adding oauthlib 3.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Finished processing dependencies for deblurrer==1.0.0
# zip_safe flag not set; analyzing archive contents...
# deblurrer.scripts.datasets.__pycache__.compile_all.cpython-36: module references __file__
# deblurrer.scripts.datasets.__pycache__.download.cpython-36: module references __file__
# deblurrer.scripts.datasets.__pycache__.generate_csv.cpython-36: module references __file__
# deblurrer.scripts.datasets.__pycache__.generate_dataset.cpython-36: module references __file__
# deblurrer.scripts.datasets.__pycache__.generate_tfrecord.cpython-36: module references __file__
# deblurrer.scripts.datasets.__pycache__.kaggle_blur.cpython-36: module references __file__
# deblurrer.scripts.training.__pycache__.alt_train.cpython-36: module references __file__
# deblurrer.scripts.training.__pycache__.test.cpython-36: module references __file__
# deblurrer.scripts.training.__pycache__.train.cpython-36: module references __file__

# %%
# Add deblurrer package to path

import sys
sys.path += ['/content/deep-deblurring']

# %% [markdown]
# # Data Download

# %%
# Setup credentials from google drive

import colab_env
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# Executes the cell in bash mode
# %%bash

python /content/deep-deblurring/deblurrer/scripts/datasets/compile_all.py
# Out:
# Downloading kaggle_blur
# Downloading blur-dataset.zip to /content/deep-deblurring/datasets/kaggle_blur
#
# Generating .csv files
# .csv files successfully generated
# Generating TFRecords
# Generating train.csv TFRecords
# Generating valid.csv TFRecords
# Generating test.csv TFRecords
# TFRecords succesfully generated
# 2020-04-01 23:17:28.325392: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 100%|██████████| 1.49G/1.49G [00:32<00:00, 48.8MB/s]2020-04-01 23:18:36.621342: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-01 23:18:36.669308: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-01 23:18:36.670052: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P4 computeCapability: 6.1
# coreClock: 1.1135GHz coreCount: 20 deviceMemorySize: 7.43GiB deviceMemoryBandwidth: 178.99GiB/s
# 2020-04-01 23:18:36.670173: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-01 23:18:36.670238: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-01 23:18:36.670271: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-01 23:18:36.670301: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-01 23:18:36.670331: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-01 23:18:36.688584: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-01 23:18:36.688687: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-01 23:18:36.688838: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-01 23:18:36.689519: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-01 23:18:36.690151: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-04-01 23:18:36.690722: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2020-04-01 23:18:36.729403: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2000165000 Hz
# 2020-04-01 23:18:36.729731: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x32ab9c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-04-01 23:18:36.729785: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-04-01 23:18:36.862238: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-01 23:18:36.862941: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x32abb80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-04-01 23:18:36.862974: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P4, Compute Capability 6.1
# 2020-04-01 23:18:36.863967: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-01 23:18:36.864354: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P4 computeCapability: 6.1
# coreClock: 1.1135GHz coreCount: 20 deviceMemorySize: 7.43GiB deviceMemoryBandwidth: 178.99GiB/s
# 2020-04-01 23:18:36.864406: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-01 23:18:36.864434: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-01 23:18:36.864450: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-01 23:18:36.864468: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-01 23:18:36.864482: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-01 23:18:36.864521: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-01 23:18:36.864541: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-01 23:18:36.864615: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-01 23:18:36.865040: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-01 23:18:36.865367: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-04-01 23:18:36.869045: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-01 23:18:43.248778: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-04-01 23:18:43.248835: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2020-04-01 23:18:43.248847: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2020-04-01 23:18:43.253380: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-01 23:18:43.253887: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-01 23:18:43.254246: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-04-01 23:18:43.254307: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6966 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)

# %% [markdown]
# # Hyper-Parameters

# %%
import os

os.environ['EPOCHS'] = '20'
os.environ['BATCH_SIZE'] = '6'
os.environ['FPN_CHANNELS'] = '128'
os.environ['GEN_LR'] = '0.00001'
os.environ['DISC_LR'] = '0.0001'
os.environ['USE_MIXED_PRECISION'] = '0'

# %% [markdown]
# # Training

# %%
# Starts training

from deblurrer.scripts.training import alt_train as train

model, gen_opt, disc_opt, strategy = train.run('/content/deep-deblurring/datasets/tfrecords')
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# Epoch 1/20
# 22/22 [==============================] - 8s 345ms/step - gen_loss: 0.4065 - disc_loss: 3.2984
# Epoch 2/20
# 22/22 [==============================] - 4s 192ms/step - gen_loss: 0.3006 - disc_loss: 4.4825
# Epoch 3/20
# 22/22 [==============================] - 4s 160ms/step - gen_loss: 0.2512 - disc_loss: 3.4099
# Epoch 4/20
# 22/22 [==============================] - 6s 260ms/step - gen_loss: 0.2131 - disc_loss: 2.8110
# Epoch 5/20
# 22/22 [==============================] - 4s 178ms/step - gen_loss: 0.1862 - disc_loss: 2.3925
# Epoch 6/20
# 22/22 [==============================] - 4s 184ms/step - gen_loss: 0.1620 - disc_loss: 2.1512
# Epoch 7/20
# 22/22 [==============================] - 6s 293ms/step - gen_loss: 0.1367 - disc_loss: 2.0790
# Epoch 8/20
# 22/22 [==============================] - 4s 199ms/step - gen_loss: 0.1229 - disc_loss: 2.1926
# Epoch 9/20
# 22/22 [==============================] - 3s 140ms/step - gen_loss: 0.1229 - disc_loss: 2.1144
# Epoch 10/20
# 22/22 [==============================] - 4s 177ms/step - gen_loss: 0.1117 - disc_loss: 2.1986
# Epoch 11/20
# 22/22 [==============================] - 4s 172ms/step - gen_loss: 0.1097 - disc_loss: 2.2643
# Epoch 12/20
# 22/22 [==============================] - 4s 194ms/step - gen_loss: 0.1034 - disc_loss: 2.2767
# Epoch 13/20
# 22/22 [==============================] - 4s 160ms/step - gen_loss: 0.1040 - disc_loss: 2.2090
# Epoch 14/20
# 22/22 [==============================] - 4s 201ms/step - gen_loss: 0.0999 - disc_loss: 2.3721
# Epoch 15/20
# 22/22 [==============================] - 4s 194ms/step - gen_loss: 0.1001 - disc_loss: 2.1823
# Epoch 16/20
# 22/22 [==============================] - 4s 190ms/step - gen_loss: 0.0998 - disc_loss: 2.1686
# Epoch 17/20
# 22/22 [==============================] - 4s 191ms/step - gen_loss: 0.0987 - disc_loss: 2.0609
# Epoch 18/20
# 22/22 [==============================] - 4s 193ms/step - gen_loss: 0.0972 - disc_loss: 2.0532
# Epoch 19/20
# 22/22 [==============================] - 3s 159ms/step - gen_loss: 0.1002 - disc_loss: 2.0366
# Epoch 20/20
# 22/22 [==============================] - 4s 204ms/step - gen_loss: 0.0949 - disc_loss: 2.0349

# %%
model, gen_opt, disc_opt, strategy = train.run(
    '/content/deep-deblurring/datasets/tfrecords',
    model,
    gen_opt,
    disc_opt,
    strategy,
)
# Out:
# Epoch 1/20
# 22/22 [==============================] - 5s 206ms/step - gen_loss: 0.0933 - disc_loss: 2.0783
# Epoch 2/20
# 22/22 [==============================] - 4s 167ms/step - gen_loss: 0.0952 - disc_loss: 2.0150
# Epoch 3/20
# 22/22 [==============================] - 4s 176ms/step - gen_loss: 0.0923 - disc_loss: 2.0060
# Epoch 4/20
# 22/22 [==============================] - 4s 189ms/step - gen_loss: 0.0918 - disc_loss: 2.0262
# Epoch 5/20
# 22/22 [==============================] - 5s 206ms/step - gen_loss: 0.0892 - disc_loss: 2.0361
# Epoch 6/20
# 22/22 [==============================] - 4s 183ms/step - gen_loss: 0.0893 - disc_loss: 2.0137
# Epoch 7/20
# 22/22 [==============================] - 4s 202ms/step - gen_loss: 0.0888 - disc_loss: 2.0067
# Epoch 8/20
# 22/22 [==============================] - 4s 168ms/step - gen_loss: 0.0879 - disc_loss: 2.0271
# Epoch 9/20
# 22/22 [==============================] - 4s 187ms/step - gen_loss: 0.0857 - disc_loss: 2.0036
# Epoch 10/20
# 22/22 [==============================] - 4s 173ms/step - gen_loss: 0.0874 - disc_loss: 2.0023
# Epoch 11/20
# 22/22 [==============================] - 4s 194ms/step - gen_loss: 0.0835 - disc_loss: 2.0021
# Epoch 12/20
# 22/22 [==============================] - 4s 162ms/step - gen_loss: 0.0857 - disc_loss: 2.0020
# Epoch 13/20
# 22/22 [==============================] - 4s 168ms/step - gen_loss: 0.0862 - disc_loss: 2.0024
# Epoch 14/20
# 22/22 [==============================] - 4s 191ms/step - gen_loss: 0.0825 - disc_loss: 2.0021
# Epoch 15/20
# 22/22 [==============================] - 4s 167ms/step - gen_loss: 0.0856 - disc_loss: 2.0013
# Epoch 16/20
# 22/22 [==============================] - 4s 192ms/step - gen_loss: 0.0805 - disc_loss: 2.0005
# Epoch 17/20
# 22/22 [==============================] - 4s 197ms/step - gen_loss: 0.0799 - disc_loss: 2.0011
# Epoch 18/20
# 22/22 [==============================] - 4s 185ms/step - gen_loss: 0.0826 - disc_loss: 2.0009
# Epoch 19/20
# 22/22 [==============================] - 4s 191ms/step - gen_loss: 0.0792 - disc_loss: 2.0017
# Epoch 20/20
# 22/22 [==============================] - 4s 189ms/step - gen_loss: 0.0801 - disc_loss: 2.0007
