# %% [markdown]
# This Notebook will present the results of the Exploratory Data Analysis

# %% [markdown]
# # Clone Repository

# %%
#Executes the cell in bash mode
# %%bash

if [ ! -d "/content/deep-deblurring/" ]; 
    then 
        git clone https://github.com/ElPapi42/deep-deblurring;
        cd deep-deblurring/
    else 
        cd deep-deblurring/; 
        git pull; 
fi;

git checkout development
cd ..
# Out:
# Already up to date.
# Branch 'preprocess' set up to track remote branch 'preprocess' from 'origin'.
# Switched to a new branch 'preprocess'

# %% [markdown]
# # Data Download

# %%
#Executes the cell in bash mode
# %%bash

python /content/deep-deblurring/deblurrer/scripts/download.py
# Out:
# Extracting files
# Extraction succesful
# /content/deep-deblurring/dataset
# 100%|██████████| 1.60G/1.60G [00:38<00:00, 42.0MiB/s]
